# %% [markdown]
# <a href="https://colab.research.google.com/github/YihanCao123/SoundAction/blob/two_tower_training/Train_Two_Tower_on_Clotho.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! wget https://zenodo.org/record/3490684/files/clotho_captions_evaluation.csv
! wget https://zenodo.org/record/3490684/files/clotho_captions_development.csv

# %%
! rm -rf /content/SoundAction
! git clone --branch two_tower_training https://github.com/YihanCao123/SoundAction

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! rm -rf /content/Clotho-Workspace
! mkdir /content/Clotho-Workspace
! mkdir /content/Clotho-Workspace/features
! cp /content/drive/MyDrive/Clotho/waveform.h5 /content/Clotho-Workspace/features

# %%
! pip install torchlibrosa
! pip install transformers

# %%
! wget https://zenodo.org/record/3987831/files/Cnn14_mAP%3D0.431.pth

# %%
# generate data with 'clotho_data_generator.py'
! wget https://zenodo.org/record/3490684/files/clotho_audio_development.7z
! sudo apt-get install p7zip
! 7za x /content/clotho_audio_development.7z

! rm -rf /content/Clotho-Final
! mkdir /content/Clotho-Final

DATASET_DIR="/content/development"
WORKSPACE="/content/Clotho-Final"

! python3 /content/SoundAction/data/clotho_data_generator.py pack_audio_files_to_hdf5 --dataset_dir=$DATASET_DIR --workspace=$WORKSPACE
# Out:
# Validating...
# 1/20251
# 2001/20251
# 4001/20251
# 6001/20251
# 8001/20251
# 10001/20251
# 12001/20251
# 14001/20251
# 16001/20251
# 18001/20251
# 20001/20251
# Write hdf5 to /content/Clotho-Test/features/waveform.h5
# Time 2427.265 s

# %%
import numpy as np
import argparse
import logging
import os
import time
import sys

sys.path.append('/content/SoundAction')

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from model.utils import move_data_to_device

from params import train_config
from data.utils import create_folder, create_logging, get_filename
from data.data_loader import AudioDataset, TrainSampler, EvaluateSampler, collate_fn
from model.models import ConcatCLS
from model.losses import get_loss_func
from model.evaluate import Eva

# %%
# Parameters

# --dataset_dir=$DATASET_DIR --workspace=$WORKSPACE --holdout_fold=1 --model_type="Transfer_Cnn14" --pretrained_checkpoint_path=$PRETRAINED_CHECKPOINT_PATH 
# --loss_type=clip_nll --augmentation='none' --learning_rate=1e-4 --batch_size=32 --resume_iteration=0 --stop_iteration=50000 --cuda

DATASET_DIR="/content/development"
WORKSPACE="/content/Clotho-Test"
PRETRAINED_CHECKPOINT_PATH = "/content/Cnn14_mAP=0.431.pth"

args = {'holdout_fold': 1,
        'stop_iteration': 50000,
        'learning_rate': 1e-5,
        'batch_size': 32,
        'model_type': "Transfer_Cnn14",
        'freeze_base': False,
        'loss_type': 'clip_nll',
        'augmentation': 'none',
        'resume_iteration': 0,
        'lr_step_size': 13000}

dataset_dir = DATASET_DIR
workspace = WORKSPACE
holdout_fold = args['holdout_fold']
model_type = args['model_type']
pretrained_checkpoint_path = PRETRAINED_CHECKPOINT_PATH
freeze_base = args['freeze_base']
loss_type = args['loss_type']
augmentation = args['augmentation']
learning_rate = args['learning_rate']
batch_size = args['batch_size']
resume_iteration = args['resume_iteration']
stop_iteration = args["stop_iteration"]
device = 'cuda' if torch.cuda.is_available() else 'cpu'
num_workers = 1

loss_func = get_loss_func(loss_type)
pretrain = True if pretrained_checkpoint_path else False

hdf5_path = os.path.join(workspace, 'features', 'waveform.h5')

checkpoints_dir = os.path.join(workspace, 'checkpoints')
create_folder(checkpoints_dir)

# Model
Model = ConcatCLS # This could be Model = Transfer_Cnn14() in our case, however, here for easy implementation, we will still use this.

model = Model(train_config.sample_rate, train_config.window_size, train_config.hop_size, train_config.mel_bins,
train_config.fmin, train_config.fmax, train_config.classes_num, train_config.freeze_base)

if pretrain:
    print("Load pretrained model from {}".format(pretrained_checkpoint_path))
    model.load_from_pretrain(pretrained_checkpoint_path)

if resume_iteration:
    resume_checkpoint_path = os.path.join(checkpoints_dir, '{}_iterations.pth'.format(resume_iteration))
    print("Load resume model from {}".format(resume_checkpoint_path))
    resume_checkpoint = torch.load(resume_checkpoint_path)
    model.load_state_dict(resume_checkpoint['model'])
    iteration = resume_checkpoint['iteration']
else:
    iteration = 0

# Data
dataset = AudioDataset()

# Generator
train_sampler = TrainSampler(
    hdf5_path=hdf5_path,
    holdout_fold=holdout_fold,
    batch_size=batch_size
)

validate_sampler = EvaluateSampler(
    hdf5_path=hdf5_path,
    holdout_fold=holdout_fold,
    batch_size=batch_size
)

# Data Loader
train_loader = torch.utils.data.DataLoader(dataset=dataset,
    batch_sampler=train_sampler, collate_fn=collate_fn,
    num_workers=num_workers, pin_memory=True
)

validate_loader = torch.utils.data.DataLoader(dataset=dataset,
    batch_sampler=validate_sampler, collate_fn=collate_fn,
    num_workers=num_workers, pin_memory=True
)

if 'cuda' in device:
    model.to(device)

# Optimizer
optimizer = optim.Adam(model.parameters(), lr=learning_rate, betas=(0.9, 0.999),
    eps=1e-08, weight_decay=0., amsgrad=True
)
# loss
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.bias', 'cls.predictions.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Load pretrained model from /content/Cnn14_mAP=0.431.pth

# %%
! rm -r /content/Clotho-Test/checkpoints/*
# Out:
# rm: cannot remove '/content/Clotho-Test/checkpoints/*': No such file or directory

# %%
loss = nn.BCELoss()
# Evaluator
evaluator = Eva(model=model)
# scheduler
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=args['lr_step_size'], gamma=0.5)

train_begin_time = time.time()

acc_save_threshold = 0.73

total_loss = 0
n = 0

# Train
print('Start Training')
model.train()
for batch_data_dict in train_loader:
            # Move data to GPU
    for key in batch_data_dict.keys():
        batch_data_dict[key] = move_data_to_device(batch_data_dict[key], device)

    optimizer.zero_grad()
    # Train
    # print([element for element in batch_data_dict['caption']])
    batch_output_dict = model(batch_data_dict['waveform'], [element for element in batch_data_dict['caption']])

    output_loss = loss(batch_output_dict, batch_data_dict['target'])
    n += 1
    total_loss += output_loss
    if iteration % 1000 == 0 and iteration > 0:
        total_loss = output_loss
        n = 1
    if iteration % 200 == 0 and iteration > 0:
        print('Iteration Number: {} Loss: {} LR: {}'.format(iteration, float(output_loss), scheduler.get_last_lr()))

    # Backward
    output_loss.backward()
    optimizer.step()
    scheduler.step()

    # Evaluate AND Save Model
    if iteration % 1000 == 0:
        print("-----------------------------------------------")
        print("Evaluating in iteration: {}".format(iteration))

        train_fin_time = time.time()
        statistics =  evaluator.evaluate(validate_loader)
        print("Validate accuracy: {:.3f}".format(statistics['accuracy']))

        if statistics['accuracy'] > acc_save_threshold:
            acc_save_threshold = statistics['accuracy']
            checkpoint = {
                'iteration': iteration,
                'two_tower_state_dict': model.audio_encoder.state_dict(),
                'cnn14_state_dict': model.state_dict()
            }
            checkpoint_path = os.path.join(checkpoints_dir, '{}_{}_{}_iterations.pth'.format(int(time.time() % 100000), iteration, acc_save_threshold))
            torch.save(checkpoint, checkpoint_path)
            print('Model saved to {}'.format(checkpoint_path))

    # Stop
    if iteration == stop_iteration:
        break

    iteration += 1
# Out:
# Start Training
# -----------------------------------------------
# Evaluating in iteration: 0
# Mean: 0.5187724232673645 Standard Deviation: 0.015822427347302437 Range: [0.4290657639503479, 0.5863184928894043]
# Validate accuracy: 0.000
# Iteration Number: 200 Loss: 0.4925774931907654 LR: [1e-05]
# Iteration Number: 400 Loss: 0.5175431966781616 LR: [1e-05]
# Iteration Number: 600 Loss: 0.49262410402297974 LR: [1e-05]
# Iteration Number: 800 Loss: 0.39231938123703003 LR: [1e-05]
# Iteration Number: 1000 Loss: 0.407196044921875 LR: [1e-05]
# -----------------------------------------------
# Evaluating in iteration: 1000
# Mean: 0.7143572568893433 Standard Deviation: 0.26683133840560913 Range: [0.012398933060467243, 0.9914548397064209]
# Validate accuracy: 0.624
# Iteration Number: 1200 Loss: 0.4288156032562256 LR: [1e-05]
# Iteration Number: 1400 Loss: 0.3864608705043793 LR: [1e-05]
# Iteration Number: 1600 Loss: 0.16219082474708557 LR: [1e-05]
# Iteration Number: 1800 Loss: 0.17413458228111267 LR: [1e-05]
# Iteration Number: 2000 Loss: 0.3057847321033478 LR: [1e-05]
# -----------------------------------------------
# Evaluating in iteration: 2000
# Mean: 0.7618237733840942 Standard Deviation: 0.3353629410266876 Range: [4.452866778592579e-05, 0.9997264742851257]
# Validate accuracy: 0.761
# Model saved to /content/Clotho-Test/checkpoints/61644_2000_0.7607407407407407_iterations.pth
# Iteration Number: 2200 Loss: 0.04695086181163788 LR: [1e-05]
# Iteration Number: 2400 Loss: 0.027136411517858505 LR: [1e-05]
# Iteration Number: 2600 Loss: 0.1617947518825531 LR: [1e-05]
# Iteration Number: 2800 Loss: 0.10686785727739334 LR: [1e-05]
# Iteration Number: 3000 Loss: 0.03847093880176544 LR: [1e-05]
# -----------------------------------------------
# Evaluating in iteration: 3000
# Mean: 0.7609739303588867 Standard Deviation: 0.37163642048835754 Range: [8.048080246680911e-08, 0.9999990463256836]
# Validate accuracy: 0.800
# Model saved to /content/Clotho-Test/checkpoints/62501_3000_0.7997530864197531_iterations.pth
# Iteration Number: 3200 Loss: 0.14535146951675415 LR: [1e-05]
# Iteration Number: 3400 Loss: 0.02083299309015274 LR: [1e-05]
# Iteration Number: 3600 Loss: 0.06659373641014099 LR: [1e-05]
# Iteration Number: 3800 Loss: 0.03997642546892166 LR: [1e-05]
# Iteration Number: 4000 Loss: 0.07887023687362671 LR: [1e-05]
# -----------------------------------------------
# Evaluating in iteration:
# -----------------------------------------------
# Evaluating in iteration: 20000
# Mean: 0.7765840888023376 Standard Deviation: 0.40002816915512085 Range: [2.111009755778292e-21, 1.0]
# Validate accuracy: 0.825

# %%
# !cp -R /content/Clotho-Test/checkpoints/* /content/drive/MyDrive/Clotho/checkpoints

# %%
# This can be use to train as well
DATASET_DIR="/content/development"
WORKSPACE="/content/Clotho-Test"
PRETRAINED_CHECKPOINT_PATH = "/content/Cnn14_mAP=0.431.pth"

! python3 /content/SoundAction/run_model.py train --dataset_dir=$DATASET_DIR --workspace=$WORKSPACE --holdout_fold=1 --model_type="Transfer_Cnn14" --pretrained_checkpoint_path=$PRETRAINED_CHECKPOINT_PATH --loss_type=clip_nll --augmentation='none' --learning_rate=1e-4 --batch_size=32 --resume_iteration=0 --stop_iteration=50000 --cuda
#! python3 /content/SoundAction/test_run_model.py train --dataset_dir=$DATASET_DIR --workspace=$WORKSPACE --holdout_fold=1 --model_type="Transfer_Cnn14" --pretrained_checkpoint_path=$PRETRAINED_CHECKPOINT_PATH --loss_type=clip_nll --augmentation='none' --learning_rate=1e-3 --batch_size=32 --resume_iteration=0 --stop_iteration=50000 --cuda
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.predictions.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Load pretrained model from /content/Cnn14_mAP=0.431.pth
# Start Training
# Iteration Number: 100 Loss: 0.6827074885368347
# Iteration Number: 200 Loss: 0.5312267541885376
# Iteration Number: 300 Loss: 0.488302618265152
# Iteration Number: 400 Loss: 0.5730589628219604
# Iteration Number: 500 Loss: 0.8088611960411072
# Iteration Number: 600 Loss: 0.6451923847198486
# Iteration Number: 700 Loss: 0.5671083331108093
# Iteration Number: 800 Loss: 0.5041448473930359
# Iteration Number: 900 Loss: 0.6513609886169434
# Iteration Number: 1000 Loss: 0.5838302969932556
# -----------------------------------------------
# Iteration: 1000
# Tutput summary:
# Array = [[0.7027391 ]
#  [0.7022794 ]
#  [0.70180845]
#  ...
#  [0.7007196 ]
#  [0.6993789 ]
#  [0.70276296]]
# Measures of Dispersion
# Minimum = 0.6748688
# Maximum = 0.7958342
# Range = 0.12096536
# Variance = 1.5331789e-05
# Standard Deviation = 0.003915583
# Mean = 0.70169693
# Target summary:
# Array = [[1.]
#  [1.]
#  [1.]
#  ...
#  [0.]
#  [1.]
#  [1.]]
# Measures of Dispersion
# Minimum = 0.0
# Maximum = 1.0
# Range = 1.0
# Variance = 0.20116447
# Standard Deviation = 0.44851363
# Mean = 0.7209877
# Validate accuracy: 0.721
# Iteration Number: 1100 Loss: 0.5433108806610107
# Iteration Number: 1200 Loss: 0.6230044364929199
# Iteration Number: 1300 Loss: 0.5950528383255005
# Iteration Number: 1400 Loss: 0.6218275427818298
# Iteration Number: 1500 Loss: 0.6214261651039124
# Iteration Number: 1600 Loss: 0.6208502650260925
# Iteration Number: 1700 Loss: 0.6533088684082031
# Iteration Number: 1800 Loss: 0.6209803819656372
# Iteration Number: 1900 Loss: 0.6210640668869019
# Iteration Number: 2000 Loss: 0.6562068462371826
# -----------------------------------------------
# Iteration: 2000
# Tutput summary:
# Array = [[0.7311385 ]
#  [0.7301506 ]
#  [0.7280898 ]
#  ...
#  [0.7302644 ]
#  [0.73022467]
#  [0.7301409 ]]
# Measures of Dispersion
# Minimum = 0.7180992
# Maximum = 0.73355097
# Range = 0.015451789
# Variance = 1.5068583e-06
# Standard Deviation = 0.0012275416
# Mean = 0.73070186
# Target summary:
# Array = [[1.]
#  [1.]
#  [1.]
#  ...
#  [0.]
#  [1.]
#  [1.]]
# Measures of Dispersion
# Minimum = 0.0
# Maximum = 1.0
# Range = 1.0
# Variance = 0.20116447
# Standard Deviation = 0.44851363
# Mean = 0.7209877
# Validate accuracy: 0.721
# Iteration Number: 2100 Loss: 0.5934914350509644
# Iteration Number: 2200 Loss: 0.6450213193893433
# Iteration Number: 2300 Loss: 0.48025721311569214
# Iteration Number: 2400 Loss: 0.5664157867431641
# Iteration Number: 2500 Loss: 0.6910583972930908
# Iteration Number: 2600 Loss: 0.6200301647186279
# Iteration Number: 2700 Loss: 0.5626261830329895
# Iteration Number: 2800 Loss: 0.5360433459281921
# Iteration Number: 2900 Loss: 0.6274219751358032
# Iteration Number: 3000 Loss: 0.5948070883750916
# -----------------------------------------------
# Iteration: 3000
# Tutput summary:
# Array = [[0.70773655]
#  [0.70703477]
#  [0.7047784 ]
#  ...
#  [0.7075887 ]
#  [0.7063288 ]
#  [0.7071788 ]]
# Measures of Dispersion
# Minimum = 0.69289786
# Maximum = 0.7149002
# Range = 0.02200234
# Variance = 1.9266565e-06
# Standard Deviation = 0.0013880405
# Mean = 0.70738655
# Target summary:
# Array = [[1.]
#  [1.]
#  [1.]
#  ...
#  [0.]
#  [1.]
#  [1.]]
# Measures of Dispersion
# Minimum = 0.0
# Maximum = 1.0
# Range = 1.0
# Variance = 0.20116447
# Standard Deviation = 0.44851363
# Mean = 0.7209877
# Validate accuracy: 0.721
# Iteration Number: 3100 Loss: 0.6477819681167603
# Iteration Number: 3200 Loss: 0.6227445006370544
# Iteration Number: 3300 Loss: 0.7136246562004089
# Iteration Number: 3400 Loss: 0.5462098717689514
# Iteration Number: 3500 Loss: 0.5659831762313843
# Iteration Number: 3600 Loss: 0.6927412748336792
# Iteration Number: 3700 Loss: 0.4390318691730499
# Iteration Number: 3800 Loss: 0.622959315776825
# Iteration Number: 3900 Loss: 0.594765841960907
# Iteration Number: 4000 Loss: 0.6218398213386536
# -----------------------------------------------
# Iteration: 4000
# Tutput summary:
# Array = [[0.7019031 ]
#  [0.70197237]
#  [0.70135206]
#  ...
#  [0.7022515 ]
#  [0.7007751 ]
#  [0.70161706]]
# Measures of Dispersion
# Minimum = 0.6752353
# Maximum = 0.72136164
# Range = 0.046126366
# Variance = 3.1140273e-06
# Standard Deviation = 0.0017646607
# Mean = 0.70220983
# Target summary:
# Array = [[1.]
#  [1.]
#  [1.]
#  ...
#  [0.]
#  [1.]
#  [1.]]
# Measures of Dispersion
# Minimum = 0.0
# Maximum = 1.0
# Range = 1.0
# Variance = 0.20116447
# Standard Deviation = 0.44851363
# Mean = 0.7209877
# Validate accuracy: 0.721
# Iteration Number: 4100 Loss: 0.5627664923667908
# Iteration Number: 4200 Loss: 0.6215125322341919
# Iteration Number: 4300 Loss: 0.6814540028572083
# Iteration Number: 4400 Loss: 0.5615023970603943
# Iteration Number: 4500 Loss: 0.6495479941368103
# Iteration Number: 4600 Loss: 0.6458770632743835
# Iteration Number: 4700 Loss: 0.5341390371322632
# Iteration Number: 4800 Loss: 0.5943002700805664
# Iteration Number: 4900 Loss: 0.6200743913650513
# Iteration Number: 5000 Loss: 0.5929348468780518
# -----------------------------------------------
# Iteration: 5000
# Tutput summary:
# Array = [[0.7395123 ]
#  [0.74509454]
#  [0.7440595 ]
#  ...
#  [0.74698406]
#  [0.73958015]
#  [0.745435  ]]
# Measures of Dispersion
# Minimum = 0.68098336
# Maximum = 0.7848098
# Range = 0.10382646
# Variance = 4.0445055e-05
# Standard Deviation = 0.006359643
# Mean = 0.7434874
# Target summary:
# Array = [[1.]
#  [1.]
#  [1.]
#  ...
#  [0.]
#  [1.]
#  [1.]]
# Measures of Dispersion
# Minimum = 0.0
# Maximum = 1.0
# Range = 1.0
# Variance = 0.20116447
# Standard Deviation = 0.44851363
# Mean = 0.7209877
# Validate accuracy: 0.721
# Iteration Number: 5100 Loss: 0.5141745209693909
# Iteration Number: 5200 Loss: 0.564177393913269
# Iteration Number: 5300 Loss: 0.5667160749435425
# Iteration Number: 5400 Loss: 0.5436967611312866
# Iteration Number: 5500 Loss: 0.4830475151538849
# Iteration Number: 5600 Loss: 0.48561161756515503
# Iteration Number: 5700 Loss: 0.6204942464828491
# Iteration Number: 5800 Loss: 0.6236224174499512
# Iteration Number: 5900 Loss: 0.7416541576385498
# Iteration Number: 6000 Loss: 0.5432672500610352
# -----------------------------------------------
# Iteration: 6000
# Tutput summary:
# Array = [[0.69971657]
#  [0.70340776]
#  [0.7052361 ]
#  ...
#  [0.707571  ]
#  [0.70060855]
#  [0.70719475]]
# Measures of Dispersion
# Minimum = 0.6474675
# Maximum = 0.8187806
# Range = 0.1713131
# Variance = 8.4903186e-05
# Standard Deviation = 0.009214292
# Mean = 0.70397013
# Target summary:
# Array = [[1.]
#  [1.]
#  [1.]
#  ...
#  [0.]
#  [1.]
#  [1.]]
# Measures of Dispersion
# Minimum = 0.0
# Maximum = 1.0
# Range = 1.0
# Variance = 0.20116447
# Standard Deviation = 0.44851363
# Mean = 0.7209877
# Validate accuracy: 0.721
# Iteration Number: 6100 Loss: 0.5948987007141113
# Iteration Number: 6200 Loss: 0.6576663255691528
# Iteration Number: 6300 Loss: 0.7280275225639343
# Iteration Number: 6400 Loss: 0.6027233600616455
# Iteration Number: 6500 Loss: 0.5614217519760132
# Iteration Number: 6600 Loss: 0.6209460496902466
# Iteration Number: 6700 Loss: 0.504370391368866
# Iteration Number: 6800 Loss: 0.7182640433311462
# Iteration Number: 6900 Loss: 0.5613281726837158
# Iteration Number: 7000 Loss: 0.6276473999023438
# -----------------------------------------------
# Iteration: 7000
# Tutput summary:
# Array = [[0.73691094]
#  [0.72891414]
#  [0.7321451 ]
#  ...
#  [0.7387577 ]
#  [0.7248468 ]
#  [0.73829985]]
# Measures of Dispersion
# Minimum = 0.6710868
# Maximum = 0.9215802
# Range = 0.2504934
# Variance = 0.00011484036
# Standard Deviation = 0.010716359
# Mean = 0.73581004
# Target summary:
# Array = [[1.]
#  [1.]
#  [1.]
#  ...
#  [0.]
#  [1.]
#  [1.]]
# Measures of Dispersion
# Minimum = 0.0
# Maximum = 1.0
# Range = 1.0
# Variance = 0.20116447
# Standard Deviation = 0.44851363
# Mean = 0.7209877
# Validate accuracy: 0.721
# Iteration Number: 7100 Loss: 0.4691258668899536
# Iteration Number: 7200 Loss: 0.47566017508506775
# Iteration Number: 7300 Loss: 0.6755378246307373
# Iteration Number: 7400 Loss: 0.6808415651321411
# Iteration Number: 7500 Loss: 0.6206889152526855
# Iteration Number: 7600 Loss: 0.5172969698905945
# Iteration Number: 7700 Loss: 0.7082732915878296
# Iteration Number: 7800 Loss: 0.6623401641845703
# Iteration Number: 7900 Loss: 0.5054095983505249
# Iteration Number: 8000 Loss: 0.5707926750183105
# -----------------------------------------------
# Iteration: 8000
# Tutput summary:
# Array = [[0.70933026]
#  [0.71045554]
#  [0.7139642 ]
#  ...
#  [0.7185193 ]
#  [0.6859348 ]
#  [0.70775956]]
# Measures of Dispersion
# Minimum = 0.63804495
# Maximum = 0.9506434
# Range = 0.31259847
# Variance = 0.0002247491
# Standard Deviation = 0.0149916345
# Mean = 0.7111249
# Target summary:
# Array = [[1.]
#  [1.]
#  [1.]
#  ...
#  [0.]
#  [1.]
#  [1.]]
# Measures of Dispersion
# Minimum = 0.0
# Maximum = 1.0
# Range = 1.0
# Variance = 0.20116447
# Standard Deviation = 0.44851363
# Mean = 0.7209877
# Validate accuracy: 0.721
# Iteration Number: 8100 Loss: 0.674456000328064
# Iteration Number: 8200 Loss: 0.5662674903869629
# Iteration Number: 8300 Loss: 0.618217408657074
# Iteration Number: 8400 Loss: 0.5318350791931152
# Iteration Number: 8500 Loss: 0.4545011520385742
# Iteration Number: 8600 Loss: 0.6001577377319336
# Iteration Number: 8700 Loss: 0.6072759628295898
# Iteration Number: 8800 Loss: 0.5951602458953857
# Iteration Number: 8900 Loss: 0.5336753129959106
# Iteration Number: 9000 Loss: 0.6259758472442627
# -----------------------------------------------
# Iteration: 9000
# Tutput summary:
# Array = [[0.67824805]
#  [0.6719806 ]
#  [0.6826723 ]
#  ...
#  [0.68463457]
#  [0.6617665 ]
#  [0.6799814 ]]
# Measures of Dispersion
# Minimum = 0.59928274
# Maximum = 0.98221886
# Range = 0.38293612
# Variance = 0.00037319976
# Standard Deviation = 0.01931838
# Mean = 0.6797883
# Target summary:
# Array = [[1.]
#  [1.]
#  [1.]
#  ...
#  [0.]
#  [1.]
#  [1.]]
# Measures of Dispersion
# Minimum = 0.0
# Maximum = 1.0
# Range = 1.0
# Variance = 0.20116447
# Standard Deviation = 0.44851363
# Mean = 0.7209877
# Validate accuracy: 0.721
# Iteration Number: 9100 Loss: 0.5403385162353516
# Iteration Number: 9200 Loss: 0.6515461206436157
# Iteration Number: 9300 Loss: 0.4751718044281006
# Iteration Number: 9400 Loss: 0.5636677742004395
# Iteration Number: 9500 Loss: 0.5319498181343079
# Iteration Number: 9600 Loss: 0.5949563980102539
# Iteration Number: 9700 Loss: 0.6562724113464355
# Iteration Number: 9800 Loss: 0.4814316928386688
# Iteration Number: 9900 Loss: 0.5697447061538696
# Iteration Number: 10000 Loss: 0.5147233009338379
# -----------------------------------------------
# Iteration: 10000
# Tutput summary:
# Array = [[0.69860977]
#  [0.70357734]
#  [0.7065068 ]
#  ...
#  [0.7104258 ]
#  [0.6677538 ]
#  [0.70290315]]
# Measures of Dispersion
# Minimum = 0.6043303
# Maximum = 0.9813716
# Range = 0.37704128
# Variance = 0.0002524144
# Standard Deviation = 0.015887555
# Mean = 0.70427096
# Target summary:
# Array = [[1.]
#  [1.]
#  [1.]
#  ...
#  [0.]
#  [1.]
#  [1.]]
# Measures of Dispersion
# Minimum = 0.0
# Maximum = 1.0
# Range = 1.0
# Variance = 0.20116447
# Standard Deviation = 0.44851363
# Mean = 0.7209877
# Validate accuracy: 0.721
# Iteration Number: 10100 Loss: 0.6250743865966797
# Iteration Number: 10200 Loss: 0.5919778347015381
# Iteration Number: 10300 Loss: 0.6478040218353271
# Iteration Number: 10400 Loss: 0.713725745677948
# Iteration Number: 10500 Loss: 0.6548362970352173
# Iteration Number: 10600 Loss: 0.5326188206672668
# Iteration Number: 10700 Loss: 0.6201064586639404
# Iteration Number: 10800 Loss: 0.5940294861793518
# Iteration Number: 10900 Loss: 0.6685976982116699
# Iteration Number: 11000 Loss: 0.5541149377822876
# -----------------------------------------------
# Iteration: 11000
# Tutput summary:
# Array = [[0.72290474]
#  [0.71063304]
#  [0.708908  ]
#  ...
#  [0.7262687 ]
#  [0.67629904]
#  [0.71774656]]
# Measures of Dispersion
# Minimum = 0.59089357
# Maximum = 0.99036247
# Range = 0.3994689
# Variance = 0.0005501681
# Standard Deviation = 0.023455663
# Mean = 0.7170273
# Target summary:
# Array = [[1.]
#  [1.]
#  [1.]
#  ...
#  [0.]
#  [1.]
#  [1.]]
# Measures of Dispersion
# Minimum = 0.0
# Maximum = 1.0
# Range = 1.0
# Variance = 0.20116447
# Standard Deviation = 0.44851363
# Mean = 0.7209877
# Validate accuracy: 0.721
# Iteration Number: 11100 Loss: 0.4562024772167206
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/dist-packages/torch/autograd/grad_mode.py", line 27, in decorate_context
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/torch/optim/adam.py", line 153, in step
#     maximize=group['maximize'])
#   File "/usr/local/lib/python3.7/dist-packages/torch/optim/_functional.py", line 103, in adam
#     denom = (max_exp_avg_sqs[i].sqrt() / math.sqrt(bias_correction2)).add_(eps)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/content/SoundAction/run_model.py", line 198, in <module>
#     train(args)
#   File "/content/SoundAction/run_model.py", line 145, in train
#     optimizer.step()
#   File "/usr/local/lib/python3.7/dist-packages/torch/optim/optimizer.py", line 88, in wrapper
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/torch/autograd/grad_mode.py", line 27, in decorate_context
#     return func(*args, **kwargs)
# KeyboardInterrupt
